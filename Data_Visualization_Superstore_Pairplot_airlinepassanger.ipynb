# %%
import os

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the dataset

# %%
os.chdir('E:\\Data Science\\Data Visualization')

# %%
dataset = pd.read_excel('Sample - Superstore.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
dataset
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 5          6  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 6          7  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 7          8  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 8          9  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 9         10  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 10        11  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 11        12  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 12        13  CA-2018-114412 2018-04-15 2018-04-20  Standard Class
# ...

# %%
len(dataset)
# Out:
# 9994

# %%
dataset.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
dataset[['Quantity']].plot.hist()

# %%
sns.distplot(dataset['Quantity'])

# %%
sns.distplot(dataset['Quantity'],kde=False)

# %%
sns.lmplot(x = 'Sales', y = 'Profit', data = dataset,col ='Segment',fit_reg=False)

# %%
sns.regplot(x = 'Sales', y = 'Profit', data = dataset, hue ='Segment',fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-040b7d64361a> in <module>
# ----> 1 sns.regplot(x = 'Sales', y = 'Profit', data = dataset, hue ='Segment',fit_reg=False)
#
# TypeError: regplot() got an unexpected keyword argument 'hue'

# %%
sns.jointplot(x = 'Sales',y = 'Profit',data = dataset)

# %%
sns.countplot(data = dataset ,y ='Category')

# %%
sns.countplot(data = dataset ,x ='Category')

# %%
sns.stripplot(data = dataset ,x = 'Category',y = 'Sales')

# %%
import os

# %%
import pandas as pd

# %%
os.chdir('E:\\Data Science\\Data Visualization')

# %%
data_pp = pd.read_excel('pairplot.xls')

# %%
data_pp
# Out:
#           Sales  Quantity  Discount     Profit
# 0      261.9600         2      0.00    41.9136
# 1      731.9400         3      0.00   219.5820
# 2       14.6200         2      0.00     6.8714
# 3      957.5775         5      0.45  -383.0310
# 4       22.3680         2      0.20     2.5164
# 5       48.8600         7      0.00    14.1694
# 6        7.2800         4      0.00     1.9656
# 7      907.1520         6      0.20    90.7152
# 8       18.5040         3      0.20     5.7825
# 9      114.9000         5      0.00    34.4700
# 10    1706.1840         9      0.20    85.3092
# 11     911.4240         4      0.20    68.3568
# 12      15.5520         3      0.20     5.4432
# 13     407.9760         3      0.20   132.5922
# 14      68.8100         5      0.80  -123.8580
# 15       2.5440         3      0.80    -3.8160
# 16     665.8800         6      0.00    13.3176
# 17      55.5000         2      0.00     9.9900
# 18       8.5600         2      0.00     2.4824
# ...

# %%
data_pp.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(data = data_pp.corr(),annot=True)

# %%
import os

# %%
os.chdir('E:\\Data Science\\Data Visualization')

# %%
data_ap = pd.read_csv('airline_passengers.csv')

# %%
data_ap
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                      112
# 1    1949-02                      118
# 2    1949-03                      132
# 3    1949-04                      129
# 4    1949-05                      121
# 5    1949-06                      135
# 6    1949-07                      148
# 7    1949-08                      148
# 8    1949-09                      136
# 9    1949-10                      119
# 10   1949-11                      104
# 11   1949-12                      118
# 12   1950-01                      115
# 13   1950-02                      126
# 14   1950-03                      141
# 15   1950-04                      135
# 16   1950-05                      125
# 17   1950-06                      149
# 18   1950-07                      170
# 19   1950-08                      170
# 20   1950-09                      158
# 21   1950-10                      133
# 22   1950-11                      114
# 23   1950-12                      140
# ...

# %%
data_ap.plot()

# %%
data_ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
# Month                      144 non-null object
# Thousands of Passengers    144 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
data_ap['Month']=pd.to_datetime(data_ap['Month'])

# %%
data_ap
# Out:
#          Month  Thousands of Passengers
# 0   1949-01-01                      112
# 1   1949-02-01                      118
# 2   1949-03-01                      132
# 3   1949-04-01                      129
# 4   1949-05-01                      121
# 5   1949-06-01                      135
# 6   1949-07-01                      148
# 7   1949-08-01                      148
# 8   1949-09-01                      136
# 9   1949-10-01                      119
# 10  1949-11-01                      104
# 11  1949-12-01                      118
# 12  1950-01-01                      115
# 13  1950-02-01                      126
# 14  1950-03-01                      141
# 15  1950-04-01                      135
# 16  1950-05-01                      125
# 17  1950-06-01                      149
# 18  1950-07-01                      170
# 19  1950-08-01                      170
# 20  1950-09-01                      158
# 21  1950-10-01                      133
# ...

# %%
data_ap.set_index('Month',inplace=True)

# %%
data_ap.plot()
